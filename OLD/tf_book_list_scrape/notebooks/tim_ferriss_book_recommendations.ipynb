# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import json
import re

from fuzzywuzzy import fuzz
from fuzzywuzzy import process

from pandasql import sqldf
pysqldf = lambda q: sqldf(q, globals())

# %%
url="https://www.booksoftitans.com/list"

# Make a GET request to fetch the raw HTML content
html_content = requests.get(
    url,
    headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
).text

# Parse the html content
soup = BeautifulSoup(html_content, "lxml")

# %%
# soup.text

# %%
table = soup.find('table', id="tablepress-3")

# %%
# str(table)

# %%
dfs = pd.read_html(str(table))
len(dfs)
# Out:
# 1

# %%
df = dfs[0]
len(df)
# Out:
# 2454

# %%
fixes = {
    'body of science': 'body by science',
    'garden cities of to morrow': 'garden cities of tomorrow',
    'poor richards almanac': 'poor richards almanack',
    'school for good and evil series': 'school for good and evil',
    'secrets of power negotiating audio': 'secrets of power negotiating',
    'humans of new york stories': 'humans of new york',
    'i thought it was just me but it isnt': 'i thought it was just me',
    'i will teach you to be rich second edition': 'i will teach you to be rich',
}

# %%
df = df.dropna(subset=['Book'])
df['base_title'] = df['Book'].apply(lambda x: re.split("[:;]+", x)[0].lower().replace("-", " "))
df['base_title'] = df['base_title'].apply(lambda x: re.sub('[^A-Za-z0-9\s]+', '', x))
df['base_title'] = df['base_title'].apply(lambda text: text[text.startswith('the ') and len('the '):])
df['base_title'] = df['base_title'].apply(lambda x: fixes[x] if x in fixes.keys() else x)
df['base_title'] = df['base_title'].apply(lambda x: x.rstrip())

# %%
df.head(10)
# Out:
#                                                 Book  \
# 0  Presto!: How I Made Over 100 Pounds Disappear ...
# 1  God, No!: Signs You May Already Be an Atheist ...
# 2                         The Art of Thought Reading
# 3  Flim-Flam! Psychics, ESP, Unicorns, and Other ...
# 4                                   The Artist's Way
# 5                                        On the Road
# 6                                       Eat for Life
# 7                                         First Bite
# 8                 Surely You're Joking, Mr. Feynman!
# 9                          The Scientist in the Crib
#
#                                               Author   Recommended By  \
# 0                                      Penn Jillette    Penn Jillette
# 1                                      Penn Jillette    Penn Jillette
# 2                                    Joseph Dunniger    Penn Jillette
# 3                                        James Randi    Penn Jillette
# 4                                      Julia Cameron    Penn Jillette
# 5                                       Jack Kerouac    Penn Jillette
# 6                                       Joel Fuhrman    Penn Jillette
# 7                                         Bee Wilson    Penn Jillette
# 8                                    Richard Feynman    Penn Jillette
# 9  Alison Gopnik, Andrew N. Meltzoff, and Patrici...  Steve Jurvetson
#
#    Podcast #                                         base_title
# 0        405                                             presto
# 1        405                                             god no
# 2        405                             art of thought reading
# 3        405  flim flam psychics esp unicorns and other delu...
# 4        405                                        artists way
# 5        405                                        on the road
# 6        405                                       eat for life
# 7        405                                         first bite
# 8        405                     surely youre joking mr feynman
# 9        404                              scientist in the crib

# %%
df[df['Book'] == '######']
# Out:
# Empty DataFrame
# Columns: [Book, Author, Recommended By, Podcast #]
# Index: []

# %%
books = pysqldf(
"""
select distinct
    df.base_title,
    book,
    author,
    df_counts.count
from df
inner join (
    select
        base_title,
        count(*) as count
    from df
    group by 1
) as df_counts on df.base_title = df_counts.base_title
order by df_counts.count desc, df.base_title
"""
)
books = books.fillna('#####')
books.head()
# Out:
#         base_title                                               Book  \
# 0  4 hour workweek                                The 4-Hour Workweek
# 1  4 hour workweek                                The 4-Hour Workweek
# 2  4 hour workweek                                The 4-Hour Workweek
# 3  4 hour workweek  The 4-Hour Workweek: Escape 9-5, Live Anywhere...
# 4  tools of titans                                    Tools of Titans
#
#                 Author  count
# 0      Timothy Ferriss     42
# 1          Tim Ferriss     42
# 2  The 4-Hour Workweek     42
# 3      Timothy Ferriss     42
# 4      Timothy Ferriss     25

# %%
bl = pysqldf(
"""
select
    base_title,
    count(*) as count
from df
group by 1
order by 2 desc
"""
)
bl = bl.fillna('#####')
bl.head(50)
# Out:
#                                base_title  count
# 0                         4 hour workweek     42
# 1                         tools of titans     25
# 2                             4 hour chef     21
# 3                             4 hour body     19
# 4                        tribe of mentors     17
# 5          surely youre joking mr feynman     14
# 6                            bird by bird     12
# 7                              black swan     12
# 8                 mans search for meaning     12
# 9                      radical acceptance     12
# 10                                sapiens     12
# 11                           tao te ching     12
# 12                      benjamin franklin     11
# 13                  magic of thinking big     11
# 14         22 immutable laws of marketing     10
# 15                    effective executive     10
# 16                 poor charlies almanack     10
# 17                 thinking fast and slow     10
# 18                            bad science      9
# 19                                   dune      9
# 20                    five minute journal      9
# 21                   fooled by randomness      9
# 22                               outliers      9
# 23                              awareness      8
# 24                     dont shoot the dog      8
# 25                       e myth revisited      8
# 26                        getting past no      8
# 27           hard thing about hard things      8
# 28  how to stop worrying and start living      8
# 29                     levels of the game      8
# 30                            meditations      8
# 31                              one thing      8
# 32                 stumbling on happiness      8
# 33                            vagabonding      8
# 34                         atlas shrugged      7
# 35                         getting to yes      7
# 36                              influence      7
# 37            searching for bobby fischer      7
# 38                        zorba the greek      7
# 39               a guide to the good life      6
# 40                    checklist manifesto      6
# 41                         essential rumi      6
# 42                      extreme ownership      6
# 43                 high output management      6
# 44                                  lying      6
# 45                                mindset      6
# 46                             principles      6
# 47                         seeking wisdom      6
# 48                             snow crash      6
# 49             stranger in a strange land      6

# %%
def cross_fuzz(df, column):
    ct = pd.crosstab(df[column].unique(), df[column].unique())
    ct = ct.apply(lambda col: [fuzz.ratio(col.name, x) for x in col.index])
    return ct

# %%
ct = cross_fuzz(bl, 'base_title')
ct.head()
# Out:
# col_0                              10 happier  100 secrets of the art world  \
# row_0
#                               100           0                             0
# 10 happier                      0         100                            32
# 100 secrets of the art world    0          32                           100
# 100 year life                   0          52                            44
# 101 knife designs               0          37                            31
#
# col_0                         100 year life  101 knife designs  \
# row_0
#                                           0                  0
# 10 happier                               52                 37
# 100 secrets of the art world             44                 31
# 100 year life                           100                 40
# 101 knife designs                        40                100
#
# col_0                         12 rules for life  13 clocks  \
# row_0
#                                               0          0
# 10 happier                                   30         21
# 100 secrets of the art world                 44         22
# 100 year life                                60         27
# 101 knife designs                            29         31
#
# col_0                         13 secrets for speaking fluent japanese  1984  \
# row_0
#                                                                     0     0
# 10 happier                                                         20    14
# 100 secrets of the art world                                       48     6
# 100 year life                                                      31    12
# 101 knife designs                                                  32    10
#
# col_0                         22 immutable laws of branding       ...         \
# row_0                                                             ...
#                                                           0       ...
# 10 happier                                               21       ...
# 100 secrets of the art world                             32       ...
# 100 year life                                            24       ...
# 101 knife designs                                        30       ...
#
# col_0                         wtf  year of living biblically  \
# row_0
#                                 0                          0
# 10 happier                      0                         11
# 100 secrets of the art world   13                         34
# 100 year life                  12                         37
# 101 knife designs              10                         24
#
# col_0                         year without pants  \
# row_0
#                                                0
# 10 happier                                    21
# 100 secrets of the art world                  35
# 100 year life                                 39
# 101 knife designs                             29
#
# col_0                         years of lyndon johnson set 4 books  \
# row_0
#                                                                 0
# 10 happier                                                     13
# 100 secrets of the art world                                   38
# 100 year life                                                  29
# 101 knife designs                                              27
#
# col_0                         you can be a stock market genius  your memory  \
# row_0
#                                                              0            0
# 10 happier                                                  19           29
# 100 secrets of the art world                                37           26
# 100 year life                                               27           33
# 101 knife designs                                           33           14
#
# col_0                         your money or your life  \
# row_0
#                                                     0
# 10 happier                                         18
# 100 secrets of the art world                       39
# 100 year life                                      44
# 101 knife designs                                  25
#
# col_0                         zen and the art of motorcycle maintenance  \
# row_0
#                                                                       0
# 10 happier                                                           20
# 100 secrets of the art world                                         41
# 100 year life                                                        30
# 101 knife designs                                                    24
#
# col_0                         zero to one  zorba the greek
# row_0
#                                         0                0
# 10 happier                             19               32
# 100 secrets of the art world           36               33
# 100 year life                          33               29
# 101 knife designs                      21               25
#
# [5 rows x 1453 columns]

# %%
matches = {}
for row_name, row in ct.iterrows():
    matched = []
    for col_name, col_value in row.iteritems():
        if (col_value < 100) and (col_value > 75):
            matched.append((col_name, col_value))
    if matched:
        matches[row_name] = matched

# %%
matches
# Out:
# {'22 immutable laws of branding': [('22 immutable laws of marketing', 85)],
#  '22 immutable laws of marketing': [('22 immutable laws of branding', 85)],
#  'a guide to the good life': [('art of the good life', 77)],
#  'a peoples history of the united states': [('oxford history of the united states',
#    82)],
#  'a walk in the woods': [('awake in the wild', 78)],
#  'art of asking': [('art of learning', 79),
#   ('art of living', 77),
#   ('art of loving', 77)],
#  'art of fielding': [('art of living', 79), ('art of loving', 79)],
#  'art of learning': [('art of asking', 79),
#   ('art of living', 79),
#   ('art of loving', 79)],
#  'art of living': [('art of asking', 77),
#   ('art of fielding', 79),
#   ('art of learning', 79),
#   ('art of loving', 92)],
#  'art of loving': [('art of asking', 77),
#   ('art of fielding', 79),
#   ('art of learning', 79),
#   ('art of living', 92)],
#  'art of the good life': [('a guide to the good life', 77)],
#  'art of war': [('war of art', 80)],
#  'autobiography of a yogi': [('autobiography of malcolm x', 78)],
#  'autobiography of malcolm x': [('autobiography of a yogi', 78)],
#  'awake in the wild': [('a walk in the woods', 78)],
#  'bad science': [('body by science', 77)],
#  'big book of jewish humor': [('big book of new american humor', 78)],
#  'big book of new american humor': [('big book of jewish humor', 78)],
#  'black swan': [('black swan green', 77)],
#  'black swan green': [('black swan', 77)],
#  'body by science': [('bad science', 77)],
#  'books of magic': [('colour of magic', 76)],
#  'born to run': [('on the run', 76)],
#  'built to last': [('built to sell', 77)],
#  'built to sell': [('built to last', 77)],
#  'colour of magic': [('books of magic', 76)],
#  'creativity': [('creativity inc', 83)],
#  'creativity inc': [('creativity', 83)],
#  'einstein': [('einsteins god', 76)],
#  'einsteins god': [('einstein', 76)],
#  'end of faith': [('speaking of faith', 76)],
#  'essential cuisine': [('essential rumi', 77), ('essentialism', 76)],
#  'essential rumi': [('essential cuisine', 77), ('essentialism', 77)],
#  'essential scratch  sniff guide to becoming a whiskey know it all': [('essential scratch and sniff guide to becoming a wine expert',
#    81)],
#  'essential scratch and sniff guide to becoming a wine expert': [('essential scratch  sniff guide to becoming a whiskey know it all',
#    81)],
#  'essentialism': [('essential cuisine', 76), ('essential rumi', 77)],
#  'fantasy bond': [('fantasyland', 78)],
#  'fantasyland': [('fantasy bond', 78)],
#  'female brain': [('male brain', 91)],
#  'fifty shades of chicken': [('fifty shades of grey', 79)],
#  'fifty shades of grey': [('fifty shades of chicken', 79)],
#  'finding my virginity': [('losing my virginity', 82)],
#  'freakonomics': [('superfreakonomics', 83)],
#  'gamble': [('game', 80)],
#  'game': [('gamble', 80)],
#  'getting things done': [('getting things done workbook', 81)],
#  'getting things done workbook': [('getting things done', 81)],
#  'god is not great': [('good to great', 76)],
#  'going clear': [('king lear', 80)],
#  'good to great': [('god is not great', 76)],
#  'happy body': [('happy money', 76)],
#  'happy money': [('happy body', 76)],
#  'heros journey': [('writers journey', 79)],
#  'homo deus': [('homo ludens', 80)],
#  'homo ludens': [('homo deus', 80)],
#  'how adam smith can change your life': [('how proust can change your life',
#    82)],
#  'how proust can change your life': [('how adam smith can change your life',
#    82)],
#  'how to bake everything': [('how to cook everything', 86)],
#  'how to cook everything': [('how to bake everything', 86),
#   ('how to cook everything the basics', 80),
#   ('how to cook everything vegetarian', 80)],
#  'how to cook everything the basics': [('how to cook everything', 80),
#   ('how to cook everything vegetarian', 79)],
#  'how to cook everything vegetarian': [('how to cook everything', 80),
#   ('how to cook everything the basics', 79)],
#  'island': [('islandia', 86)],
#  'islandia': [('island', 86)],
#  'king lear': [('going clear', 80)],
#  'letters from a stoic': [('letters from an astrophysicist', 80)],
#  'letters from an astrophysicist': [('letters from a stoic', 80)],
#  'lord of the flies': [('lord of the rings', 82)],
#  'lord of the rings': [('lord of the flies', 82)],
#  'losing my virginity': [('finding my virginity', 82)],
#  'male brain': [('female brain', 91)],
#  'marketing': [('markings', 82)],
#  'markings': [('marketing', 82)],
#  'mental toughness training for sports': [('new toughness training for sports',
#    90)],
#  'millionaire real estate agent': [('millionaire real estate investor', 85)],
#  'millionaire real estate investor': [('millionaire real estate agent', 85)],
#  'new one minute manager': [('one minute manager', 90)],
#  'new toughness training for sports': [('mental toughness training for sports',
#    90)],
#  'norton anthology of modern and contemporary poetry volume 1': [('norton anthology of modern and contemporary poetry volume 2',
#    98)],
#  'norton anthology of modern and contemporary poetry volume 2': [('norton anthology of modern and contemporary poetry volume 1',
#    98)],
#  'on the bus': [('on the run', 80)],
#  'on the road': [('on the run', 76)],
#  'on the run': [('born to run', 76), ('on the bus', 80), ('on the road', 76)],
#  'one minute manager': [('new one minute manager', 90)],
#  'oxford history of the united states': [('a peoples history of the united states',
#    82)],
#  'pihkal': [('tihkal', 83)],
#  'poor charlies almanack': [('poor richards almanack', 86)],
#  'poor richards almanack': [('poor charlies almanack', 86)],
#  'power broker': [('power of broke', 85)],
#  'power of broke': [('power broker', 85), ('power of no', 80)],
#  'power of no': [('power of broke', 80)],
#  'problems of philosophy': [('tao of philosophy', 77)],
#  'scattered': [('shattered', 89)],
#  'shattered': [('scattered', 89)],
#  'speaking of faith': [('end of faith', 76)],
#  'superfreakonomics': [('freakonomics', 83)],
#  'tao of philosophy': [('problems of philosophy', 77)],
#  'tihkal': [('pihkal', 83)],
#  'tribe': [('tribes', 91)],
#  'tribes': [('tribe', 91)],
#  'walden': [('warden', 83)],
#  'war of art': [('art of war', 80)],
#  'warden': [('walden', 83)],
#  'wealth of nations': [('wealth of networks', 80)],
#  'wealth of networks': [('wealth of nations', 80)],
#  'writers journey': [('heros journey', 79)]}

# %%
df[df['base_title'].isin(['tao te ching'])]
# Out:
#               Book                                   Author  \
# 842   Tao Te Ching                                  Lao Tzu
# 898   Tao Te Ching                                  Lao Tzu
# 1156  Tao Te Ching                                  Lao Tsu
# 1328  Tao Te Ching                                  Lao Tsu
# 1372  Tao Te Ching                                  Lao Tsu
# 1382  Tao Te Ching                                  Lao Tsu
# 1470  Tao Te Ching                                  Lao Tsu
# 1647  Tao Te Ching  Lao Tzu, Sam Torode and Ancient Renewal
# 1892  Tao Te Ching  Lao Tzu, Sam Torode and Ancient Renewal
# 2102  Tao Te Ching                                    Laozi
# 2179  Tao Te Ching                             Tao Te Ching
# 2444  Tao te Ching                      Lao Tzu Gia-Fu Feng
#
#                                      Recommended By  Podcast #    base_title
# 842     Soman Chainani / Susan Cain / Graham Duncan        292  tao te ching
# 898                                  Gretchen Rubin        290  tao te ching
# 1156                                            NaN        250  tao te ching
# 1328                                 Krista Tippett        223  tao te ching
# 1372                                 Soman Chainani        220  tao te ching
# 1382                                  Adam Robinson        219  tao te ching
# 1470  Josh Waitzkin, Ramit Sethi, and Adam Robinson        210  tao te ching
# 1647                                    Jason Nemer        182  tao te ching
# 1892                                 Naval Ravikant        136  tao te ching
# 2102                                 Laird Hamilton         89  tao te ching
# 2179                                     Rick Rubin         76  tao te ching
# 2444                                  Josh Waitzkin          2  tao te ching

# %%
flat = []
for base_title, grp in df.groupby('base_title'):
    flat.append(
        {
            'base_title': base_title,
            'title': list(grp['Book'].unique()),
            'author': list(grp['Author'].unique()),
            'recommended_by': list(grp['Recommended By'].unique()),
            'podcast_no': list(grp['Podcast #'].unique())
        }
    )
flt = pd.DataFrame(flat)
flt.head(50)
# Out:
#                                                author  \
# 0                                                 nan
# 1                                          Dan Harris
# 2                         Thomas Girst & Magnus Resch
# 3                       "Lynda Gratton, Andrew Scott"
# 4                                       Murray Carter
# 5                                     Jordan Peterson
# 6                                       James Thurber
# 7                                        Giles Murray
# 8                                       George Orwell
# 9         Al Ries & Laura Ries,Al Ries and Laura Ries
# 10        Al Ries & Jack Trout,Al Ries and Jack Trout
# 11                                      Sarah Manguso
# 12                  Eric Ripert and Veronica Chambers
# 13                        Timothy Ferriss,Tim Ferriss
# 14                        Timothy Ferriss,Tim Ferriss
# 15    Timothy Ferriss,Tim Ferriss,The 4-Hour Workweek
# 16                                      Robert Greene
# 17                                       Gary Chapman
# 18                                      Peter Mallouk
# 19                                    Richard Wiseman
# 20                      Stephen R. Covey,Steven Covey
# 21                                    Dr. Andrew Weil
# 22                                       Richard Koch
# 23                                       Richard Koch
# 24                                    Charles Dickens
# 25                                      George Orwell
# 26                                         Will Bowen
# 27                                 John Kennedy Toole
# 28                                  John S. Hendricks
# 29                    "Brian Grazer, Charles Fishman"
# 30                                    Frederick Exley
# 31                                        Harry Crews
# 32                                      Hector Garcia
# 33                                       Mark Shriver
# 34                                  William B. Irvine
# 35                                   Bertrand Russell
# 36                Marcel Mazoyer and Laurence Roudart
# 37                                        Franz Kafka
# 38                                      Marcel Proust
# 39                                     Jack Kornfield
# 40                                   Hanya Yanagihara
# 41              Christian Ziegler and Egbert G. Leigh
# 42                                        Byron Katie
# 43                                   Ernest Hemingway
# 44                                    Stephen Wolfram
# 45                                     Jack Kornfield
# 46  "Christopher Alexander, Sara Ishikawa, Murray ...
# 47                                        Howard Zinn
# 48                                       Dorian Yates
# 49                                  Burton G. Malkiel
#
#                                            base_title  \
# 0
# 1                                          10 happier
# 2                        100 secrets of the art world
# 3                                       100 year life
# 4                                   101 knife designs
# 5                                   12 rules for life
# 6                                           13 clocks
# 7             13 secrets for speaking fluent japanese
# 8                                                1984
# 9                       22 immutable laws of branding
# 10                     22 immutable laws of marketing
# 11                                      300 arguments
# 12                                           32 yolks
# 13                                        4 hour body
# 14                                        4 hour chef
# 15                                    4 hour workweek
# 16                                   48 laws of power
# 17                                   5 love languages
# 18  5 mistakes every investor makes and how to avo...
# 19                                         59 seconds
# 20                7 habits of highly effective people
# 21                          8 weeks to optimum health
# 22                                     8020 principle
# 23  8020 principle and 92 other powerful laws of n...
# 24                                  a christmas carol
# 25                             a collection of essays
# 26                             a complaint free world
# 27                            a confederacy of dunces
# 28                                a curious discovery
# 29                                     a curious mind
# 30                                       a fans notes
# 31                                  a feast of snakes
# 32                                    a geek in japan
# 33                                         a good man
# 34                           a guide to the good life
# 35                    a history of western philosophy
# 36                     a history of world agriculture
# 37                                    a hunger artist
# 38                      a la recherche du temps perdu
# 39                             a lamp in the darkness
# 40                                      a little life
# 41                                        a magic web
# 42                         a mind at home with itself
# 43                                   a moveable feast
# 44                              a new kind of science
# 45                                  a path with heart
# 46                                 a pattern language
# 47             a peoples history of the united states
# 48                         a portrait of dorian yates
# 49                     a random walk down wall street
#
#                                            podcast_no  \
# 0                                                 281
# 1                                                  50
# 2                                                 343
# 3                                                 374
# 4                                                 236
# 5                                                 332
# 6                                                 366
# 7                                         315,236,224
# 8                                         387,305,190
# 9                                             351,210
# 10                390,387,351,213,197,167,166,75,30,8
# 11                                                303
# 12                                                268
# 13  352,351,346,333,306,295,263,250,245,235,233,21...
# 14  390,370,363,352,341,330,312,306,305,295,284,25...
# 15  390,363,354,352,351,344,339,336,330,324,318,31...
# 16                                                139
# 17                                                363
# 18                                                356
# 19                                                 91
# 20                                358,328,305,170,101
# 21                                                350
# 22                                            394,363
# 23                                                196
# 24                                                259
# 25                                                290
# 26                                                122
# 27                                                222
# 28                                                157
# 29                                                279
# 30                                                110
# 31                                                145
# 32                                                125
# 33                                                 81
# 34                             382,359,329,195,125,95
# 35                                                 87
# 36                                                 82
# 37                                                245
# 38                                                303
# 39                                                300
# 40                                            292,220
# 41                                                264
# 42                                                362
# 43                                                  2
# 44                                                317
# 45                                             300,94
# 46                                        353,320,290
# 47                                            388,160
# 48                                                235
# 49                                                371
#
#                                        recommended_by  \
# 0                                       Stewart Brand
# 1                                     Dr. Peter Attia
# 2                                          Seth Godin
# 3                                         Chip Conley
# 4                                       Murray Carter
# 5                               Coach George Raveling
# 6                                         Neil Gaiman
# 7                Tim Ferriss,Murray Carter,Kevin Rose
# 8           Tristan Harris,Daniel Pink,Matt Mullenweg
# 9   "Allen Walton, Elaine Pofeldt","Josh Waitzkin,...
# 10  Tim Ferriss,Tristan Harris,"Allen Walton, Elai...
# 11                                        Frank Blake
# 12                                        Eric Ripert
# 13  Peter Attia,"Allen Walton, Elaine Pofeldt",Jam...
# 14  Tim Ferriss,Adam Savage,Peter Attia,Nick Kokon...
# 15  Tim Ferriss,Benedict Dohmen and Santiago Nesta...
# 16                                     Walter OÕBrien
# 17                                        Tim Ferriss
# 18                                      Peter Mallouk
# 19                                   Charles Poliquin
# 20  Ken Block,Tim Ferriss,Daniel Pink,Shay Carl,Re...
# 21                                    Dr. Andrew Weil
# 22                                        Tim Ferriss
# 23                                     Dave Camarillo
# 24                         Cal Fussman and Larry King
# 25                                     Gretchen Rubin
# 26                                                nan
# 27                                  Jerrod Carmichael
# 28                                          Mike Rowe
# 29                                       Brian Grazer
# 30                                      Richard Betts
# 31                                        Cal Fussman
# 32                                       Derek Sivers
# 33                                      Bryan Johnson
# 34  Safi Bahcall,Tobi Lütke,Jason Fried,David Hein...
# 35                                         Sam Harris
# 36                                           Sam Kass
# 37                                       David Blaine
# 38                                        Frank Blake
# 39                                     Jack Kornfield
# 40  Soman Chainani / Susan Cain / Graham Duncan,So...
# 41                                          Ray Dalio
# 42                                      Graham Duncan
# 43                                      Josh Waitzkin
# 44                                    Steve Jurvetson
# 45                          Jack Kornfield,Tara Brach
# 46        Patrick Collison,Liz Lambert,Gretchen Rubin
# 47                             Lisa Ling,Alex Honnold
# 48                                       Dorian Yates
# 49                                        Ramit Sethi
#
#                                                 title
# 0                                              ######
# 1                                         10% Happier
# 2                        100 Secrets of the Art World
# 3                                   The 100-Year Life
# 4   101 Knife Designs: Practical Knives for Daily Use
# 5                                   12 Rules for Life
# 6                                       The 13 Clocks
# 7             13 Secrets for Speaking Fluent Japanese
# 8                                                1984
# 9                   The 22 Immutable Laws of Branding
# 10  The 22 Immutable Laws of Marketing,The 22 Immu...
# 11                                      300 Arguments
# 12  32 Yolks: From My Mother's Table to Working th...
# 13  The 4 Hour Body,The 4-Hour Body,"The 4 Hour Bo...
# 14  The 4-Hour Chef,"The 4-Hour Chef: The Simple P...
# 15  The 4-Hour Workweek,"The 4-Hour Workweek: Esca...
# 16                               The 48 Laws of Power
# 17                               The 5 Love Languages
# 18  The 5 Mistakes Every Investor Makes and How to...
# 19     59 Seconds: Change Your Life in Under a Minute
# 20            The 7 Habits of Highly Effective People
# 21                          8 Weeks to Optimum Health
# 22                                The 80/20 Principle
# 23  The 80/20 Principle and 92 Other Powerful Laws...
# 24                                  A Christmas Carol
# 25                             A Collection of Essays
# 26                             A Complaint Free World
# 27                            A Confederacy of Dunces
# 28       A Curious Discovery: An Entrepreneur's Story
# 29        A Curious Mind: The Secret to a Bigger Life
# 30                                      A Fan's Notes
# 31                                  A Feast of Snakes
# 32  "A Geek in Japan: Discovering the Land of Mang...
# 33  "A Good Man: Rediscovering My Father, Sargent ...
# 34  A Guide to the Good Life,A Guide to the Good L...
# 35                    A History of Western Philosophy
# 36  A History of World Agriculture: From the Neoli...
# 37                                    A Hunger Artist
# 38                      A la recherche du temps perdu
# 39                             A Lamp in the Darkness
# 40                                      A Little Life
# 41   A Magic Web: The Forest of Barro Colorado Island
# 42                         A Mind at Home with Itself
# 43                                   A Moveable Feast
# 44                              A New Kind of Science
# 45  A Path with Heart,A Path with Heart: A Guide T...
# 46  A Pattern Language,"A Pattern Language: Towns,...
# 47            A People's History of the United States
# 48                         A Portrait of Dorian Yates
# 49                     A Random Walk Down Wall Street

# %%
len(flt)
# Out:
# 1453

# %%
flt.to_json('tim_ferriss_book_reccommendations.json', orient='records')
