# %%
import json
import requests
import itertools
import xmltodict

import pandas as pd
from pprint import pprint
from datetime import datetime

# %%
url="https://www.mostrecommendedbooks.com/sitemap.xml"

# Make a GET request to fetch the raw HTML content
xml_content = requests.get(
    url,
    headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
).text

# %%
sitemap = xmltodict.parse(
    xml_content,
    #process_namespaces=True
)

# %%
sitemap.keys()
# Out:
# odict_keys(['urlset'])

# %%
locs = [
    site['loc'].split('/')[-1]
    for site in sitemap['urlset']['url']
    if site['loc'].split('/')[-1]
]
locs
# Out:
# ['elon-musk-twitter-books',
#  'aj-jacobs-books',
#  'adam-fisher-books',
#  'adam-gazzaley-books',
#  'adam-robinson-books',
#  'adam-savage-books',
#  'alain-de-botton-books',
#  'alex-blumberg-books',
#  'alex-honnold-books',
#  'alexis-ohanian-books',
#  'alice-little-books',
#  'amanda-palmer-books',
#  'amelia-boone-books',
#  'andrew-zimmern-books',
#  'aniela-gregorek-books',
#  'ann-miura-ko-books',
#  'annie-mist-orisdottir-books',
#  'arianna-huffington-books',
#  'arnold-schwarzenegger-books',
#  'art-de-vany-books',
#  'ashton-kutcher-books',
#  'astro-teller-books',
#  'aubrey-marcus-books',
#  'ayaan-hirsi-ali-books',
#  'bj-novak-books',
#  'bj-miller-books',
#  'barack-obama-books',
#  'bear-grylls-books',
#  'ben-horowitz-books',
#  'ben-shapiro-books',
#  'ben-silbermann-books',
#  'ben-stiller-books',
#  'bill-gates-books',
#  'bill-nye-books',
#  'bill-rasmussen-books',
#  'blake-mycoskie-books',
#  'bob-metcalfe-books',
#  'bozoma-saint-john-books',
#  'brandon-stanton-books',
#  'brendan-moynihan-books',
#  'brene-brown-books',
#  'brian-armstrong-books',
#  'brian-chesky-books',
#  'brian-grazer-books',
#  'brian-koppelman-books',
#  'brian-mackenzie-books',
#  'bryan-callen-books',
#  'bryan-johnson-books',
#  'cal-fussman-books',
#  'caroline-paul-books',
#  'casey-neistat-books',
#  'caterina-fake-books',
#  'chade-meng-tan-books',
#  'charles-koch-books',
#  'charles-poliquin-books',
#  'charlie-munger-books',
#  'chase-jarvis-books',
#  'chelsea-handler-books',
#  'cheryl-strayed-books',
#  'chip-conley-books',
#  'chris-anderson-books',
#  'chris-fussell-books',
#  'chris-sacca-books',
#  'chris-young-books',
#  'christopher-sommer-books',
#  'cindy-eckert-books',
#  'cory-booker-books',
#  'craig-newmark-books',
#  'dj-vlad-books',
#  'dan-engle-books',
#  'dan-gable-books',
#  'daniel-ek-books',
#  'daniel-negreanu-books',
#  'daniel-pink-books',
#  'danielle-teller-books',
#  'darren-aronofsky-books',
#  'dave-camarillo-books',
#  'dave-elitch-books',
#  'david-allen-books',
#  'david-blaine-books',
#  'david-heinemeier-hansson-books',
#  'david-lynch-books',
#  'david-sabatini-books',
#  'daymond-john-books',
#  'debbie-millman-books',
#  'derek-sivers-books',
#  'diddy-books',
#  'dita-von-teese-books',
#  'dominic-dagostino-books',
#  'dorian-yates-books',
#  'doris-kearns-goodwin-books',
#  'doug-mcmillon-books',
#  'dr-andrew-weil-books',
#  'dr-gabor-mate-books',
#  'dr-martin-gibala-books',
#  'dr-phil-zimbardo-books',
#  'drew-houston-books',
#  'dustin-moskovitz-books',
#  'ed-catmull-books',
#  'ed-cooke-books',
#  'ed-zschau-books',
#  'edward-norton-books',
#  'elon-musk-books',
#  'emma-watson-books',
#  'eric-ripert-books',
#  'eric-schmidt-books',
#  'eric-weinstein-books',
#  'esther-dyson-books',
#  'esther-perel-books',
#  'ev-williams-books',
#  'evan-goldberg-books',
#  'evan-spiegel-books',
#  'ezra-klein-books',
#  'fedor-holz-books',
#  'frank-blake-books',
#  'gabby-reece-books',
#  'gary-vaynerchuk-books',
#  'george-raveling-books',
#  'glenn-beck-books',
#  'graham-duncan-books',
#  'greg-mckeown-books',
#  'greg-norman-books',
#  'gretchen-rubin-books',
#  'hamilton-morris-books',
#  'howard-marks-books',
#  'howard-schultz-books',
#  'jack-dorsey-books',
#  'jack-kornfield-books',
#  'jacqueline-novogratz-books',
#  'james-altucher-books',
#  'james-cameron-books',
#  'james-fadiman-books',
#  'jamie-foxx-books',
#  'jane-mcgonigal-books',
#  'jason-calacanis-books',
#  'jason-fried-books',
#  'jason-khalipa-books',
#  'jason-nemer-books',
#  'jason-silva-books',
#  'jeff-bezos-books',
#  'jerrod-carmichael-books',
#  'jerry-colonna-books',
#  'jerzy-gregorek-books',
#  'jesse-williams-books',
#  'jim-collins-books',
#  'jimmy-chin-books',
#  'jimmy-fallon-books',
#  'jocko-willink-books',
#  'joe-de-sena-books',
#  'joe-gebbia-books',
#  'joe-rogan-books',
#  'joel-mchale-books',
#  'joel-stein-books',
#  'john-arnold-books',
#  'john-crowley-books',
#  'jon-call-books',
#  'jon-favreau-books',
#  'jonathan-eisen-books',
#  'jonathan-sacks-books',
#  'jordan-peterson-books',
#  'joseph-gordon-levitt-books',
#  'josh-waitzkin-books',
#  'joshua-skenes-books',
#  'julia-galef-books',
#  'julie-rice-books',
#  'justin-boreta-books',
#  'jerome-jarre-books',
#  'kara-swisher-books',
#  'karlie-kloss-books',
#  'kaskade-books',
#  'katie-couric-books',
#  'katrin-davidsdottir-books',
#  'keith-rabois-books',
#  'kelly-slater-books',
#  'kelly-starrett-books',
#  'ken-block-books',
#  'ken-burns-books',
#  'kevin-kelly-books',
#  'kevin-rose-books',
#  'kevin-systrom-books',
#  'krista-tippett-books',
#  'kristen-ulmer-books',
#  'kyle-maynard-books',
#  'laird-hamilton-books',
#  'larry-ellison-books',
#  'larry-king-books',
#  'larry-page-books',
#  'laura-r-walker-books',
#  'lebron-james-books',
#  'leo-babauta-books',
#  'lewis-cantley-books',
#  'lisa-ling-books',
#  'lisa-randall-books',
#  'liv-boeree-books',
#  'liz-lambert-books',
#  'luis-von-ahn-books',
#  'm-sanjayan-books',
#  'malcolm-gladwell-books',
#  'marc-andreessen-books',
#  'marc-benioff-books',
#  'marc-goodman-books',
#  'margaret-cho-books',
#  'maria-popova-books',
#  'maria-sharapova-books',
#  'marie-forleo-books',
#  'marie-kondo-books',
#  'mark-bell-books',
#  'mark-bittman-books',
#  'mark-cuban-books',
#  'mark-hart-books',
#  'mark-zuckerberg-books',
#  'martin-polanco-books',
#  'matt-mullenweg-books',
#  'matt-ridley-books',
#  'maurice-ashley-books',
#  'max-levchin-books',
#  'michael-gervais-books',
#  'michael-mccullough-books',
#  'michael-pollan-books',
#  'mike-birbiglia-books',
#  'mike-maples-jr-books',
#  'mike-phillips-books',
#  'mike-rowe-books',
#  'mike-shinoda-books',
#  'morgan-spurlock-books',
#  'mr-money-mustache-books',
#  'muna-abusulayman-books',
#  'murray-carter-books',
#  'naval-ravikant-books',
#  'navdeep-chandel-books',
#  'neil-gaiman-books',
#  'neil-strauss-books',
#  'neil-degrasse-tyson-books',
#  'nicholas-mccarthy-books',
#  'nick-ganju-books',
#  'nick-kokonas-books',
#  'nick-szabo-books',
#  'nick-thompson-books',
#  'noah-kagan-books',
#  'oprah-winfrey-books',
#  'patrick-arnold-books',
#  'patrick-collison-books',
#  'patton-oswalt-books',
#  'paul-graham-books',
#  'paul-stamets-books',
#  'pavel-tsatsouline-books',
#  'peter-attia-books',
#  'peter-diamandis-books',
#  'peter-mallouk-books',
#  'peter-thiel-books',
#  'phil-keoghan-books',
#  'phil-libin-books',
#  'rainn-wilson-books',
#  'ramit-sethi-books',
#  'ray-dalio-books',
#  'reed-hastings-books',
#  'reid-hoffman-books',
#  'ricardo-semler-books',
#  'richa-chadha-books',
#  'richard-betts-books',
#  'richard-branson-books',
#  'rick-rubin-books',
#  'robert-rodriguez-books',
#  'rolf-potts-books',
#  'ron-conway-books',
#  'ryan-flaherty-books',
#  'ryan-holiday-books',
#  'ryan-hoover-books',
#  'ryan-shea-books',
#  'safi-bahcall-books',
#  'sam-harris-books',
#  'sam-kass-books',
#  'samin-nosrat-books',
#  'samy-kamkar-books',
#  'sarah-lewis-books',
#  'scott-adams-books',
#  'scott-belsky-books',
#  'sebastian-junger-books',
#  'seth-godin-books',
#  'seth-rogen-books',
#  'sharon-salzberg-books',
#  'shaun-white-books',
#  'shay-carl-books',
#  'soman-chainani-books',
#  'sophia-amoruso-books',
#  'stanislav-grof-books',
#  'stanley-mcchrystal-books',
#  'stephanie-mcmahon-books',
#  'stephen-dubner-books',
#  'steve-aoki-books',
#  'steve-jobs-books',
#  'steve-jurvetson-books',
#  'steven-pinker-books',
#  'steven-pressfield-books',
#  'stewart-brand-books',
#  'strauss-zelnick-books',
#  'susan-cain-books',
#  'suzy-amis-cameron-books',
#  'tara-brach-books',
#  'terry-crews-books',
#  'terry-laughlin-books',
#  'tim-ferriss-books',
#  'tim-oreilly-books',
#  'tim-urban-books',
#  'tobi-lutke-books',
#  'tom-peters-books',
#  'tommy-vietor-books',
#  'tony-hsieh-books',
#  'tony-robbins-books',
#  'tracy-dinunzio-books',
#  'travis-brewer-books',
#  'travis-kalanick-books',
#  'tristan-harris-books',
#  'turia-pitt-books',
#  'veronica-belmont-books',
#  'vince-vaughn-books',
#  'vlad-tenev-books',
#  'vlad-zamfir-books',
#  'walter-isaacson-books',
#  'warren-buffett-books',
#  'whitney-cummings-books',
#  'whitney-wolfe-herd-books',
#  'will-macaskill-books',
#  'will-smith-books',
#  'wim-hof-books',
#  'yuval-noah-harari-books',
#  'zooko-wilcox-books']

# %%
def get_recommender_json(url, f_base="https://www.mostrecommendedbooks.com/page-data/{stub}/page-data.json"):
    # Make a GET request to fetch the raw HTML content
    book_reccommendations = requests.get(
        f_base.format(stub=url),
        headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
    ).json()
    return book_reccommendations

# %%
def extract_book_recommendations(json_response):
    try:
        return json_response['result']['data']['recommenderBooks']['recommenderBooks']
    except KeyError:
        return None

# %%
books, errors = [], []
for loc in locs:
    try:
        exp = get_recommender_json(loc)
    except:
        errors.append(loc)
        continue
    results = extract_book_recommendations(exp)
    if results:
        books.extend(results)
len(books)
# Out:
# 3664

# %%
errors
# Out:
# []

# %%
books[:5]
# Out:
# [{'author': 'Steven Pinker',
#   'imageUrl': '/img/books/2EnlightenmentNow.png',
#   'newLink': 'https://amzn.to/38dsTjH',
#   'title': 'Enlightenment Now',
#   'subtitle': 'The Case for Reason, Science, Humanism, and Progress',
#   'recommenders': [{'name': 'A.J. Jacobs'},
#    {'name': 'Bill Gates'},
#    {'name': 'Jordan Peterson'},
#    {'name': 'Sam Harris'}]},
#  {'author': 'Sam Harris',
#   'imageUrl': '/img/books/3FreeWill.png',
#   'newLink': 'https://amzn.to/2v3bc8d',
#   'title': 'Free Will',
#   'subtitle': '',
#   'recommenders': [{'name': 'A.J. Jacobs'}]},
#  {'author': 'Adam Mansbach',
#   'imageUrl': '/img/books/4GotheFktoSleep.png',
#   'newLink': 'https://amzn.to/2RamwIv',
#   'title': 'Go the F**k to Sleep',
#   'subtitle': '',
#   'recommenders': [{'name': 'A.J. Jacobs'}]},
#  {'author': '',
#   'imageUrl': '/img/books/5HolyBible.png',
#   'newLink': 'https://amzn.to/3atfXbi',
#   'title': 'Holy Bible',
#   'subtitle': '',
#   'recommenders': [{'name': 'A.J. Jacobs'},
#    {'name': 'Caterina Fake'},
#    {'name': 'Kevin Kelly'},
#    {'name': 'Laird Hamilton'},
#    {'name': 'Neil deGrasse Tyson'},
#    {'name': 'Peter Thiel'},
#    {'name': 'Ricardo Semler'},
#    {'name': 'Ryan Flaherty'},
#    {'name': 'Walter Isaacson'},
#    {'name': 'Wim Hof'}]},
#  {'author': 'Sam Harris',
#   'imageUrl': '/img/books/6Lying.png',
#   'newLink': 'https://amzn.to/2NJj3hV',
#   'title': 'Lying',
#   'subtitle': '',
#   'recommenders': [{'name': 'A.J. Jacobs'},
#    {'name': 'Brian Armstrong'},
#    {'name': 'Elon Musk'},
#    {'name': 'Tim Ferriss'}]}]

# %%
df = pd.DataFrame(books)

# %%
len(df)
# Out:
# 3664

# %%
len(df['title'].unique())
# Out:
# 2654

# %%
len(df['author'].unique())
# Out:
# 2039

# %%
df.head()
# Out:
#           author                          imageUrl                  newLink  \
# 0  Steven Pinker  /img/books/2EnlightenmentNow.png  https://amzn.to/38dsTjH
# 1     Sam Harris          /img/books/3FreeWill.png  https://amzn.to/2v3bc8d
# 2  Adam Mansbach    /img/books/4GotheFktoSleep.png  https://amzn.to/2RamwIv
# 3                        /img/books/5HolyBible.png  https://amzn.to/3atfXbi
# 4     Sam Harris             /img/books/6Lying.png  https://amzn.to/2NJj3hV
#
#                                         recommenders  \
# 0  [{'name': 'A.J. Jacobs'}, {'name': 'Bill Gates...
# 1                          [{'name': 'A.J. Jacobs'}]
# 2                          [{'name': 'A.J. Jacobs'}]
# 3  [{'name': 'A.J. Jacobs'}, {'name': 'Caterina F...
# 4  [{'name': 'A.J. Jacobs'}, {'name': 'Brian Arms...
#
#                                             subtitle                 title
# 0  The Case for Reason, Science, Humanism, and Pr...     Enlightenment Now
# 1                                                                Free Will
# 2                                                     Go the F**k to Sleep
# 3                                                               Holy Bible
# 4                                                                    Lying

# %%
flattened = df.copy()
flattened['recommenders'] = flattened['recommenders'].apply(lambda x: [y['name'] for y in x])
flattened = flattened.groupby(['title', 'subtitle', 'author']).agg({'recommenders': 'sum'}).reset_index()
flattened['recommenders'] = flattened['recommenders'].apply(lambda x: list(set(x)))
flattened['recommendations'] = flattened['recommenders'].apply(lambda x: len(x))
flattened.sort_values('recommendations', ascending=False, inplace=True)

# %%
flattened
# Out:
#                                          title  \
# 1017                  Man's Search for Meaning
# 1602                       The 4-Hour Workweek
# 1415                                   Sapiens
# 1333                                Principles
# 203                             Atlas Shrugged
# 1617                             The Alchemist
# 1870                          The Fountainhead
# 747                                 Holy Bible
# 735                     High Output Management
# 1689                            The Black Swan
# 488                                       Dune
# 1977                   The Innovator's Dilemma
# 2444                   Thinking, Fast and Slow
# 2471                           Tools of Titans
# 1526                                Steve Jobs
# 1307                   Poor Charlie's Almanack
# 2386                            The War of Art
# 1577                              Tao Te Ching
# 857                                  Influence
# 1725                   The Checklist Manifesto
# 264                               Bird by Bird
# 1673           The Better Angels of Our Nature
# 2669                               Zero to One
# 768    How To Win Friends and Influence People
# 0         "Surely You're Joking, Mr. Feynman!"
# 2271                          The Selfish Gene
# 1928          The Hard Thing About Hard Things
# 245                          Benjamin Franklin
# 234                        Becoming Steve Jobs
# 1255                                  Outliers
# ...                                        ...
# 994                                 Lucky Fish
# 995                            Lud-in-the-Mist
# 996                     Lulu's Provençal Table
# 998                                    Macbeth
# 1000                  Machines of Loving Grace
# 1001                             Madame Bovary
# 1002                             Made to Stick
# 1003          Mae West on Sex, Health, and ESP
# 1004          Magic Mushrooms Around the World
# 1005                     Magicians of the Gods
# 987                   Love Letters to the Dead
# 985                                 Lou Gehrig
# 962                           Limits to Growth
# 984                                 Lost Ocean
# 963                           Limping on Water
# 995                                       [Neil Gaiman]                1
# 996                                      [Samin Nosrat]                1
# 998                                        [Susan Cain]                1
# 1000                                    [Stewart Brand]                1
# 1001                                     [Esther Perel]                1
# 1002                                  [Brian Armstrong]                1
# 1003                                   [Dita Von Teese]                1
# 1004                                  [Hamilton Morris]                1
# 1005                                    [Aubrey Marcus]                1
# 987                                       [Emma Watson]                1
# 985                                        [Larry King]                1
# 962                                        [Bill Gates]                1
# 984                                   [Richard Branson]                1
# 963                                    [Warren Buffett]                1
# 964                                    [David Sabatini]                1
# 965                                        [Bill Gates]                1
# 966                                      [Esther Perel]                1
# 967                                        [Seth Godin]                1
# 968                                    [Gretchen Rubin]                1
# 969                                   [Jordan Peterson]                1
# 970                                    [Naval Ravikant]                1
# 971                                    [Cheryl Strayed]                1
# 972                                  [Mike Maples, Jr.]                1
# 974                                    [Charlie Munger]                1
# 975                                       [Ev Williams]                1
# 976                                       [Neil Gaiman]                1
# 981                                      [Keith Rabois]                1
# 982                                       [Neil Gaiman]                1
# 2672                                       [Bill Gates]                1
#
# [2673 rows x 5 columns]

# %%
flattened.loc[1017]['recommenders']
# Out:
# ['Tony Robbins',
#  'Michael Gervais',
#  'Turia Pitt',
#  'Ryan Holiday',
#  'Daniel Pink',
#  'Dave Elitch',
#  'Chelsea Handler',
#  'Aniela Gregorek',
#  'Emma Watson',
#  'Ev Williams',
#  'Fedor Holz',
#  'Maria Popova',
#  'Naval Ravikant',
#  'David Blaine',
#  'Jocko Willink',
#  'Jimmy Fallon',
#  'Bryan Johnson',
#  'Terry Crews',
#  'Chip Conley',
#  'Esther Perel',
#  'Jordan Peterson']

# %%
len(flattened)
# Out:
# 2673

# %%
flattened['source'] = 'mostrecommendedbooks'
flattened['date_accessed'] = datetime.now()

# %%
flattened.head()
# Out:
#                          title  \
# 1017  Man's Search for Meaning
# 1602       The 4-Hour Workweek
# 1415                   Sapiens
# 1333                Principles
# 203             Atlas Shrugged
#
#                                               subtitle             author  \
# 1017                                                     Viktor E. Frankl
# 1602  Escape 9-5, Live Anywhere, and Join the New Rich    Timothy Ferriss
# 1415                      A Brief History of Humankind  Yuval Noah Harari
# 1333                                     Life and Work          Ray Dalio
# 203                                                              Ayn Rand
#
#                                            recommenders  recommendations  \
# 1017  [Tony Robbins, Michael Gervais, Turia Pitt, Ry...               21
# 1602  [Daniel Pink, Eric Weinstein, Jason Silva, Tri...               16
# 1415  [Whitney Cummings, Ashton Kutcher, Richard Bra...               15
# 1333  [Kevin Systrom, Mark Cuban, Howard Marks, Brya...               12
# 203   [Ev Williams, Joe De Sena, Brian Armstrong, Ga...               11
#
#                     source              date_accessed
# 1017  mostrecommendedbooks 2020-02-03 21:19:44.906348
# 1602  mostrecommendedbooks 2020-02-03 21:19:44.906348
# 1415  mostrecommendedbooks 2020-02-03 21:19:44.906348
# 1333  mostrecommendedbooks 2020-02-03 21:19:44.906348
# 203   mostrecommendedbooks 2020-02-03 21:19:44.906348
